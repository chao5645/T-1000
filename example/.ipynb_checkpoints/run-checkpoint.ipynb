# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F

from ray import tune
from ray.tune.schedulers import ASHAScheduler

class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # In this example, we don't change the model architecture
        # due to simplicity.
        self.conv1 = nn.Conv2d(1, 3, kernel_size=3)
        self.fc = nn.Linear(192, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 3))
        x = x.view(-1, 192)
        x = self.fc(x)
        out = F.log_softmax(x, dim=1)
        return out



# Change these values if you want the training to run quicker or slower.
EPOCH_SIZE = 512
TEST_SIZE = 256

def train(model, optimizer, train_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # We set this just for the example to run quickly.
        if batch_idx * len(data) > EPOCH_SIZE:
            return
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()


def test(model, data_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(data_loader):
            # We set this just for the example to run quickly.
            if batch_idx * len(data) > TEST_SIZE:
                break
            data, target = data.to(device), target.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

    return correct / total

def train_mnist(config):
    # Data Setup
    mnist_transforms = transforms.Compose(
        [transforms.ToTensor(),
         transforms.Normalize((0.1307, ), (0.3081, ))])

    train_loader = DataLoader(
        datasets.MNIST("/Users/xichao.chen/Work/source/T-1000x/data", train=True, download=False, transform=mnist_transforms),
        batch_size=64,
        shuffle=True)
    test_loader = DataLoader(
        datasets.MNIST("/Users/xichao.chen/Work/source/T-1000x/data", train=False, download=False, transform=mnist_transforms),
        batch_size=64,
        shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = ConvNet()
    model.to(device)

    optimizer = optim.SGD(
        model.parameters(), lr=config["lr"], momentum=config["momentum"])
    for i in range(50):
        train(model, optimizer, train_loader)
        acc = test(model, test_loader)

        # Send the current training result back to Tune
        tune.report(mean_accuracy=acc, hello="world")

        if i % 5 == 0:
            # This saves the model to the trial directory
            torch.save(model.state_dict(), "/Users/xichao.chen/Work/source/T-1000x/example/model.pth")

search_space = {
    "lr": tune.sample_from(lambda spec: 10**(-10 * np.random.rand())),
    "momentum": tune.uniform(0.1, 0.9)
}

# Uncomment this to enable distributed execution
# `ray.init(address="auto")`

# Download the dataset first
datasets.MNIST("/Users/xichao.chen/Work/source/T-1000x/data", train=True, download=False)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /Users/xichao.chen/Work/source/T-1000x/data
#     Split: Train

# %%
from hyperopt import hp
from ray.tune.suggest.hyperopt import HyperOptSearch

space = {
    "lr": hp.loguniform("lr", 1e-10, 0.1),
    "momentum": hp.uniform("momentum", 0.1, 0.9),
}

hyperopt_search = HyperOptSearch(space, metric="mean_accuracy", mode="max")

analysis = tune.run(train_mnist, num_samples=10, search_alg=hyperopt_search)

# Obtain a trial dataframe from all run trials of this `tune.run` call.
dfs = analysis.trial_dataframes

# Plot by epoch
ax = None  # This plots everything on the same plot
for d in dfs.values():
    ax = d.mean_accuracy.plot(ax=ax, legend=False)
# Out:
# == Status ==<br>Memory usage on this node: 9.3/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/12 CPUs, 0/0 GPUs, 0.0/4.64 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/xichao.chen/ray_results/train_mnist_2021-03-23_18-34-03<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status  </th><th>loc  </th><th style="text-align: right;">     lr</th><th style="text-align: right;">  momentum</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_49816ba6</td><td>RUNNING </td><td>     </td><td style="text-align: right;">1.01796</td><td style="text-align: right;">  0.763767</td></tr>
# </tbody>
# </table><br><br>
# Result for train_mnist_4984ec04:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: ca7202039db748d98615f87f3abffeff
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.0375
#   node_ip: 192.168.139.23
#   pid: 51519
#   time_since_restore: 0.37584495544433594
#   time_this_iter_s: 0.37584495544433594
#   time_total_s: 0.37584495544433594
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 4984ec04
#
# Result for train_mnist_49816ba6:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: 7fafd1f1520a47e7bb2c23f6c7a0f9f1
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.0125
#   node_ip: 192.168.139.23
#   pid: 51518
#   time_since_restore: 0.38965916633605957
#   time_this_iter_s: 0.38965916633605957
#   time_total_s: 0.38965916633605957
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 49816ba6
#
# Result for train_mnist_49890320:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: efc5a780c46e45b2b2615986a6e0bbea
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.225
#   node_ip: 192.168.139.23
#   pid: 51553
#   time_since_restore: 0.3942878246307373
#   time_this_iter_s: 0.3942878246307373
#   time_total_s: 0.3942878246307373
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '49890320'
#
# Result for train_mnist_49878b76:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: 747667bee53b46d7a0953995ac29b936
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.121875
#   node_ip: 192.168.139.23
#   pid: 51550
#   time_since_restore: 0.40067195892333984
#   time_this_iter_s: 0.40067195892333984
#   time_total_s: 0.40067195892333984
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 49878b76
#
# Result for train_mnist_498634c4:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: b73273db68304428b540e143d83e29a3
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.103125
#   node_ip: 192.168.139.23
#   pid: 51551
#   time_since_restore: 0.4100520610809326
#   time_this_iter_s: 0.4100520610809326
#   time_total_s: 0.4100520610809326
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 498634c4
#
# Result for train_mnist_498ab21a:
#   date: 2021-03-23_18-34-05
#   done: false
#   experiment_id: 8235a6e02c5740d7a6e12534a9df28f2
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.05625
#   node_ip: 192.168.139.23
#   pid: 51561
#   time_since_restore: 0.39981603622436523
#   time_this_iter_s: 0.39981603622436523
#   time_total_s: 0.39981603622436523
#   timestamp: 1616495645
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 498ab21a
#
# Result for train_mnist_498d9232:
#   date: 2021-03-23_18-34-06
#   done: false
#   experiment_id: 7652a30eacec4684833d69bdeacf8987
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.025
#   node_ip: 192.168.139.23
#   pid: 51562
#   time_since_restore: 0.40131616592407227
#   time_this_iter_s: 0.40131616592407227
#   time_total_s: 0.40131616592407227
#   timestamp: 1616495646
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 498d9232
#
# Result for train_mnist_498f3c54:
#   date: 2021-03-23_18-34-06
#   done: false
#   experiment_id: 38cac5a9227b4a03b834078eb889852e
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 1
#   mean_accuracy: 0.0625
#   node_ip: 192.168.139.23
#   pid: 51563
#   time_since_restore: 0.39566683769226074
#   time_this_iter_s: 0.39566683769226074
#   time_total_s: 0.39566683769226074
#   timestamp: 1616495646
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id:
# <tr><td>train_mnist_4991043a</td><td>RUNNING </td><td>192.168.139.23:51570</td><td style="text-align: right;">1.04296</td><td style="text-align: right;">  0.710818</td><td style="text-align: right;">0.06875 </td><td style="text-align: right;">     7</td><td style="text-align: right;">         2.35757</td></tr>
# <tr><td>train_mnist_49a39c58</td><td>RUNNING </td><td>192.168.139.23:51571</td><td style="text-align: right;">1.00999</td><td style="text-align: right;">  0.530386</td><td style="text-align: right;">0.084375</td><td style="text-align: right;">     7</td><td style="text-align: right;">         2.36994</td></tr>
# </tbody>
# </table><br><br>
# Result for train_mnist_49816ba6:
#   date: 2021-03-23_18-34-10
#   done: false
#   experiment_id: 7fafd1f1520a47e7bb2c23f6c7a0f9f1
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.121875
#   node_ip: 192.168.139.23
#   pid: 51518
#   time_since_restore: 5.418284177780151
#   time_this_iter_s: 0.34658384323120117
#   time_total_s: 5.418284177780151
#   timestamp: 1616495650
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 49816ba6
#
# Result for train_mnist_4984ec04:
#   date: 2021-03-23_18-34-10
#   done: false
#   experiment_id: ca7202039db748d98615f87f3abffeff
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.121875
#   node_ip: 192.168.139.23
#   pid: 51519
#   time_since_restore: 5.426605939865112
#   time_this_iter_s: 0.37284183502197266
#   time_total_s: 5.426605939865112
#   timestamp: 1616495650
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 4984ec04
#
# Result for train_mnist_498d9232:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: 7652a30eacec4684833d69bdeacf8987
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.075
#   node_ip: 192.168.139.23
#   pid: 51562
#   time_since_restore: 5.404922008514404
#   time_this_iter_s: 0.31597900390625
#   time_total_s: 5.404922008514404
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 498d9232
#
# Result for train_mnist_498634c4:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: b73273db68304428b540e143d83e29a3
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.11875
#   node_ip: 192.168.139.23
#   pid: 51551
#   time_since_restore: 5.515822172164917
#   time_this_iter_s: 0.3324861526489258
#   time_total_s: 5.515822172164917
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 498634c4
#
# Result for train_mnist_4991043a:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: 4e71d8dbb5ea4ec0a3da3937b9ad39a4
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.10625
#   node_ip: 192.168.139.23
#   pid: 51570
#   time_since_restore: 5.405191898345947
#   time_this_iter_s: 0.32660508155822754
#   time_total_s: 5.405191898345947
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 4991043a
#
# Result for train_mnist_498f3c54:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: 38cac5a9227b4a03b834078eb889852e
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 16
#   mean_accuracy: 0.090625
#   node_ip: 192.168.139.23
#   pid: 51563
#   time_since_restore: 5.475414752960205
#   time_this_iter_s: 0.3236680030822754
#   time_total_s: 5.475414752960205
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 16
#   trial_id: 498f3c54
#
# Result for train_mnist_49890320:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: efc5a780c46e45b2b2615986a6e0bbea
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 17
#   mean_accuracy: 0.10625
#   node_ip: 192.168.139.23
#   pid: 51553
#   time_since_restore: 5.688287973403931
#   time_this_iter_s: 0.3390030860900879
#   time_total_s: 5.688287973403931
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 17
#   trial_id: '49890320'
#
# Result for train_mnist_49878b76:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: 747667bee53b46d7a0953995ac29b936
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 17
#   mean_accuracy: 0.10625
#   node_ip: 192.168.139.23
#   pid: 51550
#   time_since_restore: 5.717365741729736
#   time_this_iter_s: 0.334226131439209
#   time_total_s: 5.717365741729736
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 17
#   trial_id: 49878b76
#
# Result for train_mnist_498ab21a:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: 8235a6e02c5740d7a6e12534a9df28f2
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 17
#   mean_accuracy: 0.071875
#   node_ip: 192.168.139.23
#   pid: 51561
#   time_since_restore: 5.714545965194702
#   time_this_iter_s: 0.34156298637390137
#   time_total_s: 5.714545965194702
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 17
#   trial_id: 498ab21a
#
# Result for train_mnist_49a39c58:
#   date: 2021-03-23_18-34-11
#   done: false
#   experiment_id: e08253a22fee463f9ed3a9d2a1a6870e
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 17
#   mean_accuracy: 0.1
#   node_ip: 192.168.139.23
#   pid: 51571
#   time_since_restore: 5.7409398555755615
#   time_this_iter_s: 0.35278797149658203
#   time_total_s: 5.7409398555755615
#   timestamp: 1616495651
#   timesteps_since_restore: 0
#   training_iteration: 17
#   trial_id: 49a39c58
# == Status ==<br>Memory usage on this node: 10.0/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 10/12 CPUs, 0/0 GPUs, 0.0/4.64 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /Users/xichao.chen/ray_results/train_mnist_2021-03-23_18-34-03<br>Number of trials: 10/10 (10 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status  </th><th>loc                 </th><th style="text-align: right;">     lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_49816ba6</td><td>RUNNING </td><td>192.168.139.23:51518</td><td style="text-align: right;">1.01796</td><td style="text-align: right;">  0.763767</td><td style="text-align: right;">0.075   </td><td style="text-align: right;">    24</td><td style="text-align: right;">         8.12855</td></tr>
# <tr><td>train_mnist_4984ec04</td><td>RUNNING </td><td>192.168.139.23:51519</td><td style="text-align: right;">1.05951</td><td style="text-align: right;">  0.479947</td><td style="text-align: right;">0.096875</td><td style="text-align: right;">    24</td><td style="text-align: right;">         8.14848</td></tr>
# <tr><td>train_mnist_498634c4</td><td>RUNNING </td><td>192.168.139.23:51551</td><td style="text-align: right;">1.06105</td><td style="text-align: right;">  0.621933</td><td style="text-align: right;">0.11875 </td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.67705</td></tr>
# <tr><td>train_mnist_49878b76</td><td>RUNNING </td><td>192.168.139.23:51550</td><td style="text-align: right;">1.02017</td><td style="text-align: right;">  0.274981</td><td style="text-align: right;">0.103125</td><td style="text-align: right;">    23</td><td style="text-align: right;">         7.80779</td></tr>
# <tr><td>train_mnist_49890320</td><td>RUNNING </td><td>192.168.139.23:51553</td><td style="text-align: right;">1.03939</td><td style="text-align: right;">  0.223693</td><td style="text-align: right;">0.090625</td><td style="text-align: right;">    23</td><td style="text-align: right;">         7.73024</td></tr>
# <tr><td>train_mnist_498ab21a</td><td>RUNNING </td><td>192.168.139.23:51561</td><td style="text-align: right;">1.09555</td><td style="text-align: right;">  0.106037</td><td style="text-align: right;">0.096875</td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.4491 </td></tr>
# <tr><td>train_mnist_498d9232</td><td>RUNNING </td><td>192.168.139.23:51562</td><td style="text-align: right;">1.10374</td><td style="text-align: right;">  0.547219</td><td style="text-align: right;">0.0875  </td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.43252</td></tr>
# <tr><td>train_mnist_498f3c54</td><td>RUNNING </td><td>192.168.139.23:51563</td><td style="text-align: right;">1.08723</td><td style="text-align: right;">  0.350248</td><td style="text-align: right;">0.103125</td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.553  </td></tr>
# <tr><td>train_mnist_4991043a</td><td>RUNNING </td><td>192.168.139.23:51570</td><td style="text-align: right;">1.04296</td><td style="text-align: right;">  0.710818</td><td style="text-align: right;">0.09375 </td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.43307</td></tr>
# <tr><td>train_mnist_49a39c58</td><td>RUNNING </td><td>192.168.139.23:51571</td><td style="text-align: right;">1.00999</td><td style="text-align: right;">  0.530386</td><td style="text-align: right;">0.1375  </td><td style="text-align: right;">    22</td><td style="text-align: right;">         7.48059</td></tr>
# </tbody>
# </table><br><br>
# Result for train_mnist_49816ba6:
#   date: 2021-03-23_18-34-15
#   done: false
#   experiment_id: 7fafd1f1520a47e7bb2c23f6c7a0f9f1
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 31
#   mean_accuracy: 0.11875
#   node_ip: 192.168.139.23
#   pid: 51518
#   time_since_restore: 10.591087102890015
#   time_this_iter_s: 0.3503279685974121
#   time_total_s: 10.591087102890015
#   timestamp: 1616495655
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 49816ba6
#
# Result for train_mnist_4984ec04:
#   date: 2021-03-23_18-34-15
#   done: false
#   experiment_id: ca7202039db748d98615f87f3abffeff
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 31
#   mean_accuracy: 0.10625
#   node_ip: 192.168.139.23
#   pid: 51519
#   time_since_restore: 10.650273084640503
#   time_this_iter_s: 0.3529510498046875
#   time_total_s: 10.650273084640503
#   timestamp: 1616495655
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 4984ec04
#
# Result for train_mnist_498634c4:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: b73273db68304428b540e143d83e29a3
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 30
#   mean_accuracy: 0.10625
#   node_ip: 192.168.139.23
#   pid: 51551
#   time_since_restore: 10.556209087371826
#   time_this_iter_s: 0.35558485984802246
#   time_total_s: 10.556209087371826
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 30
#   trial_id: 498634c4
#
# Result for train_mnist_498d9232:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: 7652a30eacec4684833d69bdeacf8987
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 31
#   mean_accuracy: 0.08125
#   node_ip: 192.168.139.23
#   pid: 51562
#   time_since_restore: 10.602396249771118
#   time_this_iter_s: 0.3458380699157715
#   time_total_s: 10.602396249771118
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 498d9232
#
# Result for train_mnist_4991043a:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: 4e71d8dbb5ea4ec0a3da3937b9ad39a4
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 31
#   mean_accuracy: 0.090625
#   node_ip: 192.168.139.23
#   pid: 51570
#   time_since_restore: 10.618786811828613
#   time_this_iter_s: 0.3476848602294922
#   time_total_s: 10.618786811828613
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 4991043a
#
# Result for train_mnist_498f3c54:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: 38cac5a9227b4a03b834078eb889852e
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 31
#   mean_accuracy: 0.1125
#   node_ip: 192.168.139.23
#   pid: 51563
#   time_since_restore: 10.718941926956177
#   time_this_iter_s: 0.33963489532470703
#   time_total_s: 10.718941926956177
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 498f3c54
#
# Result for train_mnist_49890320:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: efc5a780c46e45b2b2615986a6e0bbea
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 32
#   mean_accuracy: 0.115625
#   node_ip: 192.168.139.23
#   pid: 51553
#   time_since_restore: 10.889128923416138
#   time_this_iter_s: 0.3478240966796875
#   time_total_s: 10.889128923416138
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: '49890320'
#
# Result for train_mnist_49878b76:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: 747667bee53b46d7a0953995ac29b936
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 32
#   mean_accuracy: 0.09375
#   node_ip: 192.168.139.23
#   pid: 51550
#   time_since_restore: 10.94857668876648
#   time_this_iter_s: 0.359846830368042
#   time_total_s: 10.94857668876648
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: 49878b76
#
# Result for train_mnist_498ab21a:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: 8235a6e02c5740d7a6e12534a9df28f2
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 32
#   mean_accuracy: 0.1
#   node_ip: 192.168.139.23
#   pid: 51561
#   time_since_restore: 11.023447036743164
#   time_this_iter_s: 0.3700590133666992
#   time_total_s: 11.023447036743164
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: 498ab21a
#
# Result for train_mnist_49a39c58:
#   date: 2021-03-23_18-34-16
#   done: false
#   experiment_id: e08253a22fee463f9ed3a9d2a1a6870e
#   hello: world
#   hostname: MacBook
#   iterations_since_restore: 32
#   mean_accuracy: 0.09375
#   node_ip: 192.168.139.23
#   pid: 51571
#   time_since_restore: 11.051438808441162
#   time_this_iter_s: 0.3712918758392334
#   time_total_s: 11.051438808441162
#   timestamp: 1616495656
#   timesteps_since_restore: 0
#   training_iteration: 32
#   trial_id: 49a39c58
# == Status ==<br>Memory usage on this node: 10.0/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: